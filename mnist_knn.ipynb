# %%
import tensorflow as tf
import numpy as np

# %%
# input_data contains MNIST dataset which is present in tensorflow lib, we will access it using the below statement 
from tensorflow.examples.tutorials.mnist import input_data
# Below read_data_sets allows us to read 'GZIP' files directly, and the GZIP files stored in 'mnist_data' 
mnist = input_data.read_data_sets("mnist_data/", one_hot=True)
# Out:
# Extracting mnist_data/train-images-idx3-ubyte.gz
# Extracting mnist_data/train-labels-idx1-ubyte.gz
# Extracting mnist_data/t10k-images-idx3-ubyte.gz
# Extracting mnist_data/t10k-labels-idx1-ubyte.gz

# %%
# out of 60,000 training set we are taking 5000 only for now
training_digits, training_labels = mnist.train.next_batch(5000)
test_digits, test_labels = mnist.test.next_batch(200)

# %%
# float is for grayscale images, since float will contain intensity values
# 'None' represent index of each image, since we have no idea how many images we will pass 
training_digits_pl = tf.placeholder("float", [None,784])
# below we represent a test image as a vector with size 784 
test_digits_pl = tf.placeholder("float", [784])    # WE ONLY HAVE 1 TEST DIGIT

# %%
# Nearest Neighbour calcculation using L1 distance
# WE HAVE 1 TEST DIGIT WHICH WE NEED TO COMPARE WITH TRAINING DIGITS
# firstly we change the sign of all the pixel values of test digit then ADD to each of the training digit pixels
l1_distance = tf.abs(tf.add(training_digits_pl, tf.negative(test_digits_pl)))

# %%
# we want to find those images from training set which are closest to test image
# tf.reduce_sum()->reduces each vector into a single value, that is the distance from test image
distance = tf.reduce_sum(l1_distance, axis=1)

# %%
# HERE WE ARE USING K=1 (IN KNN algo)
# prediction: get min distance index (nearest neighbor)
pred = tf.argmin(distance,0)  # tf.arg_min() for previous versions

# %%
accuracy=0.

#initializing the variables
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    
    #loop over test data
    for i in range(len(test_digits)):
        # get nearest neighbor 
        nn_index = sess.run(pred,feed_dict={training_digits_pl: training_digits,test_digits_pl: test_digits[i, :]})
       # get nearest neighbor class label and compare it to its true label
        print("Test",i, "Prediction:", np.argmax(training_labels[nn_index]), "True Label:",np.argmax(test_labels[i]))
        # nn_index--> this will contain the nearest neighbor in training set (nearest to test set) , a no. b/w 0-9 which is 
        # present in 1-hot notation
        #np.argmax(test_labels[i])--> this gives the value of test digit (a value from 0-9) which is present in 1-hot notation
        #calculate accuracy
        if np.argmax(training_labels[nn_index])==np.argmax(test_labels[i]):
            accuracy +=1./len(test_digits)
    print("Done!")
    print("Accuracy:", accuracy)
# Out:
# Test 0 Prediction: 4 True Label: 4
# Test 1 Prediction: 5 True Label: 5
# Test 2 Prediction: 2 True Label: 2
# Test 3 Prediction: 3 True Label: 3
# Test 4 Prediction: 4 True Label: 5
# Test 5 Prediction: 3 True Label: 3
# Test 6 Prediction: 2 True Label: 2
# Test 7 Prediction: 2 True Label: 2
# Test 8 Prediction: 0 True Label: 0
# Test 9 Prediction: 5 True Label: 5
# Test 10 Prediction: 0 True Label: 0
# Test 11 Prediction: 2 True Label: 2
# Test 12 Prediction: 1 True Label: 1
# Test 13 Prediction: 9 True Label: 9
# Test 14 Prediction: 5 True Label: 5
# Test 15 Prediction: 5 True Label: 3
# Test 16 Prediction: 2 True Label: 2
# Test 17 Prediction: 3 True Label: 3
# Test 18 Prediction: 4 True Label: 4
# Test 19 Prediction: 8 True Label: 8
# Test 20 Prediction: 1 True Label: 1
# Test 21 Prediction: 4 True Label: 4
# Test 22 Prediction: 2 True Label: 2
# Test 23 Prediction: 7 True Label: 7
# Test 24 Prediction: 1 True Label: 1
# Test 25 Prediction: 2 True Label: 2
# Test 26 Prediction: 3 True Label: 3
# Test 27 Prediction: 7 True Label: 7
# Test 28 Prediction: 9 True Label: 9
# Test 29 Prediction: 7 True Label: 7
# Test 30 Prediction: 1 True Label: 1
# Test 31 Prediction: 5 True Label: 5
# Test 32 Prediction: 1 True Label: 1
# Test 33 Prediction: 0 True Label: 0
# Test 34 Prediction: 3 True Label: 3
# Test 35 Prediction: 0 True Label: 0
# Test 36 Prediction: 3 True Label: 8
# Test 37 Prediction: 4 True Label: 4
# Test 38 Prediction: 6 True Label: 6
# Test 39 Prediction: 6 True Label: 6
# Test 40 Prediction: 8 True Label: 8
# Test 41 Prediction: 5 True Label: 5
# Test 42 Prediction: 6 True Label: 6
# Test 43 Prediction: 3 True Label: 3
# Test 44 Prediction: 2 True Label: 2
# Test 45 Prediction: 1 True Label: 1
# Test 46 Prediction: 4 True Label: 4
# Test 47 Prediction: 8 True Label: 8
# Test 48 Prediction: 3 True Label: 3
# Test 49 Prediction: 9 True Label: 9
# Test 50 Prediction: 1 True Label: 1
# Test 51 Prediction: 4 True Label: 4
# Test 52 Prediction: 2 True Label: 2
# Test 53 Prediction: 4 True Label: 4
# Test 54 Prediction: 8 True Label: 8
# Test 55 Prediction: 0 True Label: 0
# Test 56 Prediction: 0 True Label: 0
# Test 57 Prediction: 8 True Label: 8
# Test 58 Prediction: 3 True Label: 3
# Test 59 Prediction: 6 True Label: 6
# Test 60 Prediction: 1 True Label: 1
# Test 61 Prediction: 2 True Label: 2
# Test 62 Prediction: 1 True Label: 1
# Test 63 Prediction: 5 True Label: 5
# Test 64 Prediction: 0 True Label: 0
# Test 65 Prediction: 5 True Label: 5
# Test 66 Prediction: 3 True Label: 3
# Test 67 Prediction: 9 True Label: 9
# Test 68 Prediction: 1 True Label: 1
# Test 69 Prediction: 6 True Label: 6
# Test 70 Prediction: 3 True Label: 3
# Test 71 Prediction: 7 True Label: 7
# Test 72 Prediction: 1 True Label: 1
# Test 73 Prediction: 3 True Label: 3
# Test 74 Prediction: 8 True Label: 8
# Test 75 Prediction: 1 True Label: 1
# Test 76 Prediction: 6 True Label: 6
# Test 77 Prediction: 3 True Label: 3
# Test 78 Prediction: 7 True Label: 7
# Test 79 Prediction: 3 True Label: 3
# Test 80 Prediction: 7 True Label: 7
# Test 81 Prediction: 2 True Label: 2
# Test 82 Prediction: 4 True Label: 4
# Test 83 Prediction: 2 True Label: 2
# Test 84 Prediction: 6 True Label: 6
# Test 85 Prediction: 1 True Label: 1
# Test 86 Prediction: 0 True Label: 0
# Test 87 Prediction: 3 True Label: 3
# Test 88 Prediction: 1 True Label: 1
# Test 89 Prediction: 0 True Label: 0
# Test 90 Prediction: 2 True Label: 2
# Test 91 Prediction: 3 True Label: 3
# Test 92 Prediction: 7 True Label: 7
# Test 93 Prediction: 5 True Label: 5
# Test 94 Prediction: 7 True Label: 7
# Test 95 Prediction: 7 True Label: 7
# Test 96 Prediction: 1 True Label: 1
# Test 97 Prediction: 8 True Label: 8
# Test 98 Prediction: 7 True Label: 7
# Test 99 Prediction: 0 True Label: 0
# Test 100 Prediction: 5 True Label: 3
# Test 101 Prediction: 3 True Label: 5
# Test 102 Prediction: 5 True Label: 5
# Test 103 Prediction: 4 True Label: 4
# Test 104 Prediction: 8 True Label: 8
# Test 105 Prediction: 2 True Label: 2
# Test 106 Prediction: 7 True Label: 7
# Test 107 Prediction: 0 True Label: 0
# Test 108 Prediction: 0 True Label: 0
# Test 109 Prediction: 4 True Label: 4
# Test 110 Prediction: 5 True Label: 5
# Test 111 Prediction: 2 True Label: 2
# Test 112 Prediction: 5 True Label: 5
# Test 113 Prediction: 5 True Label: 5
# Test 114 Prediction: 7 True Label: 7
# Test 115 Prediction: 9 True Label: 9
# Test 116 Prediction: 9 True Label: 9
# Test 117 Prediction: 7 True Label: 7
# Test 118 Prediction: 0 True Label: 0
# Test 119 Prediction: 4 True Label: 4
# Test 120 Prediction: 4 True Label: 4
# Test 121 Prediction: 7 True Label: 7
# Test 122 Prediction: 0 True Label: 0
# Test 123 Prediction: 0 True Label: 0
# Test 124 Prediction: 1 True Label: 1
# Test 125 Prediction: 3 True Label: 3
# Test 126 Prediction: 2 True Label: 2
# Test 127 Prediction: 1 True Label: 1
# Test 128 Prediction: 7 True Label: 9
# Test 129 Prediction: 1 True Label: 1
# Test 130 Prediction: 5 True Label: 5
# Test 131 Prediction: 1 True Label: 1
# Test 132 Prediction: 1 True Label: 1
# Test 133 Prediction: 4 True Label: 4
# Test 134 Prediction: 7 True Label: 7
# Test 135 Prediction: 7 True Label: 7
# Test 136 Prediction: 2 True Label: 2
# Test 137 Prediction: 2 True Label: 2
# Test 138 Prediction: 0 True Label: 0
# Test 139 Prediction: 8 True Label: 8
# Test 140 Prediction: 1 True Label: 1
# Test 141 Prediction: 6 True Label: 6
# Test 142 Prediction: 2 True Label: 2
# Test 143 Prediction: 8 True Label: 8
# Test 144 Prediction: 7 True Label: 7
# Test 145 Prediction: 4 True Label: 4
# Test 146 Prediction: 0 True Label: 0
# Test 147 Prediction: 7 True Label: 7
# Test 148 Prediction: 7 True Label: 3
# Test 149 Prediction: 9 True Label: 9
# Test 150 Prediction: 5 True Label: 5
# Test 151 Prediction: 4 True Label: 4
# Test 152 Prediction: 6 True Label: 6
# Test 153 Prediction: 9 True Label: 9
# Test 154 Prediction: 5 True Label: 5
# Test 155 Prediction: 2 True Label: 2
# Test 156 Prediction: 2 True Label: 2
# Test 157 Prediction: 2 True Label: 2
# Test 158 Prediction: 6 True Label: 6
# Test 159 Prediction: 7 True Label: 7
# Test 160 Prediction: 5 True Label: 3
# Test 161 Prediction: 1 True Label: 1
# Test 162 Prediction: 5 True Label: 5
# Test 163 Prediction: 4 True Label: 5
# Test 164 Prediction: 2 True Label: 2
# Test 165 Prediction: 8 True Label: 8
# Test 166 Prediction: 1 True Label: 1
# Test 167 Prediction: 5 True Label: 5
# Test 168 Prediction: 2 True Label: 2
# Test 169 Prediction: 5 True Label: 5
# Test 170 Prediction: 6 True Label: 6
# Test 171 Prediction: 0 True Label: 0
# Test 172 Prediction: 1 True Label: 1
# Test 173 Prediction: 6 True Label: 6
# Test 174 Prediction: 4 True Label: 4
# Test 175 Prediction: 1 True Label: 1
# Test 176 Prediction: 5 True Label: 5
# Test 177 Prediction: 5 True Label: 5
# Test 178 Prediction: 8 True Label: 8
# Test 179 Prediction: 7 True Label: 7
# Test 180 Prediction: 0 True Label: 0
# Test 181 Prediction: 0 True Label: 0
# Test 182 Prediction: 5 True Label: 5
# Test 183 Prediction: 1 True Label: 6
# Test 184 Prediction: 9 True Label: 9
# Test 185 Prediction: 3 True Label: 3
# Test 186 Prediction: 0 True Label: 0
# Test 187 Prediction: 1 True Label: 7
# Test 188 Prediction: 7 True Label: 7
# Test 189 Prediction: 7 True Label: 7
# Test 190 Prediction: 0 True Label: 0
# Test 191 Prediction: 3 True Label: 3
# Test 192 Prediction: 4 True Label: 4
# Test 193 Prediction: 0 True Label: 0
# Test 194 Prediction: 7 True Label: 7
# Test 195 Prediction: 3 True Label: 3
# Test 196 Prediction: 9 True Label: 9
# Test 197 Prediction: 1 True Label: 1
# Test 198 Prediction: 5 True Label: 3
# Test 199 Prediction: 2 True Label: 2
# Done!
# Accuracy: 0.9400000000000007
